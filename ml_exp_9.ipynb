# %% [markdown]
# <a href="https://colab.research.google.com/github/Dineshchowdary9999/Case1E2/blob/main/ml_exp_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=101)
kmeans = KMeans(n_clusters=4)
kmeans.fit(data[0])
print("K-Means Cluster Centers")
print(kmeans.cluster_centers_)
print("K-Means Labels")
print(kmeans.labels_)
# Out:
# K-Means Cluster Centers
# [[ 3.71749226  7.01388735]
#  [-9.46941837 -6.56081545]
#  [-0.0123077   2.13407664]
#  [-4.13591321  7.95389851]]
# K-Means Labels
# [3 0 2 0 0 1 0 2 0 2 3 2 0 0 3 2 0 2 1 3 1 2 2 1 3 1 1 2 0 0 3 1 0 2 2 3 1
#  1 1 2 1 3 3 3 2 0 3 2 1 2 2 3 0 2 1 3 2 2 3 0 1 0 1 3 0 2 1 0 0 1 0 2 1 2
#  1 0 0 2 3 2 2 1 0 1 2 2 2 3 2 1 1 1 1 2 2 1 0 3 1 0 2 1 2 2 0 2 1 0 1 1 0
#  3 3 0 1 0 3 3 0 3 2 3 2 3 2 0 3 2 1 3 3 3 2 1 1 3 0 3 0 2 1 0 1 3 3 0 2 1
#  3 3 3 3 2 0 2 3 0 0 0 2 0 2 2 3 1 3 2 0 3 2 0 2 3 0 2 3 0 0 1 0 3 1 1 3 1
#  1 1 1 1 2 1 0 0 3 1 2 0 0 1 2]

# %%
f,(ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
