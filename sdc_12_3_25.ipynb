# %% [markdown]
# <a href="https://colab.research.google.com/github/Dineshchowdary9999/Case1E2/blob/main/sdc_12_3_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install scikit-learn pandas numpy

# %%
import pandas as pd
df=pd.read_csv("pima-indians-diabetes.csv")
df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
columns=["pregnancies","glucose","bloodpressure","skinthickness","insulin","bmi","dbfunction","age","outcome"]
df.columns=columns
df.head()
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    dbfunction  age  outcome
# 0       0.351   31        0
# 1       0.672   32        1
# 2       0.167   21        0
# 3       2.288   33        1
# 4       0.201   30        0

# %%
df.isnull().sum()
# Out:
# pregnancies      0
# glucose          0
# bloodpressure    0
# skinthickness    0
# insulin          0
# bmi              0
# dbfunction       0
# age              0
# outcome          0
# dtype: int64

# %%
df.describe()
# Out:
#        pregnancies     glucose  bloodpressure  skinthickness     insulin  \
# count   767.000000  767.000000     767.000000     767.000000  767.000000
# mean      3.842243  120.859192      69.101695      20.517601   79.903520
# std       3.370877   31.978468      19.368155      15.954059  115.283105
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               bmi  dbfunction         age     outcome
# count  767.000000  767.000000  767.000000  767.000000
# mean    31.990482    0.471674   33.219035    0.348110
# std      7.889091    0.331497   11.752296    0.476682
# min      0.000000    0.078000   21.000000    0.000000
# ...

# %%
x=df.drop("outcome",axis="columns")
y=df.outcome

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled[:7]
# Out:
# array([[-0.84372629, -1.12208597, -0.16024856,  0.53202348, -0.69355921,
#         -0.68372895, -0.36426474, -0.18894038],
#        [ 1.23423997,  1.94447577, -0.26357823, -1.28688187, -0.69355921,
#         -1.10230105,  0.60470064, -0.1037951 ],
#        [-0.84372629, -0.99692019, -0.16024856,  0.15569823,  0.12235685,
#         -0.49346891, -0.91968415, -1.0403932 ],
#        [-1.14057861,  0.50506924, -1.50353429,  0.90834872,  0.76467376,
#          1.40913155,  5.48273197, -0.01864981],
#        [ 0.343683  , -0.15205113,  0.25307013, -1.28688187, -0.69355921,
#         -0.81056898, -0.8170523 , -0.27408566],
#        [-0.25002164, -1.34112609, -0.98688593,  0.7201861 ,  0.07027711,
#         -0.12563282, -0.67517887, -0.61466679],
#        [ 1.82794462, -0.18334258, -3.57012772, -1.28688187, -0.69355921,
#          0.41977931, -1.01929741, -0.35923094]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y)

# %%
x_train.shape
# Out:
# (575, 8)

# %%
x_test.shape
# Out:
# (192, 8)

# %%
y_train.value_counts()
# Out:
# outcome
# 0    369
# 1    206
# Name: count, dtype: int64

# %%
202/373
# Out:
# 0.5415549597855228

# %%
y_test.value_counts()
# Out:
# outcome
# 0    131
# 1     61
# Name: count, dtype: int64

# %%
67/125
# Out:
# 0.536

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
score=cross_val_score(DecisionTreeClassifier(),x,y,cv=5)
score
# Out:
# array([0.71428571, 0.68181818, 0.7124183 , 0.75163399, 0.73202614])

# %%
score.mean()
# Out:
# 0.7184364654952891

# %%
from sklearn.ensemble import BaggingClassifier
model=BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=50,
    max_samples=0.7,
    oob_score=True,
    random_state=0
)
model.fit(x_train,y_train)
model.oob_score_
# Out:
# 0.7460869565217392
