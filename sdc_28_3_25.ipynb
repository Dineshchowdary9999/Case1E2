# %% [markdown]
# <a href="https://colab.research.google.com/github/Dineshchowdary9999/Case1E2/blob/main/sdc_28_3_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import random

# %%
image=cv2.imread("Royality Bala.jpg")
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
resized=cv2.resize(image,(256,256))
plt.imshow(resized)
plt.show()

# %%
flip=cv2.flip(image,1)
plt.imshow(flip)
plt.show()

# %%
blur=cv2.GaussianBlur(image,(15,15),0)
plt.imshow(blur)
plt.show()

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(gray,threshold1=50,threshold2=150)
plt.imshow(edges,cmap='gray')
plt.show()
